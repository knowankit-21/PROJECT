# %%
# import library
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\coding\python\MY CSV\marksheet-1.csv")
df
# Out:
#    SUBJECT  TOTAL
# 0  ENGLISH     72
# 1    HINDI     82
# 2    MATHS     73
# 3  SCIENCE     81
# 4      SST     74

# %%
plt.pie(
    df["TOTAL"],
    labels=df["SUBJECT"],
    autopct="%0.1f%%",
    colors=["red", "blue", "pink", "green", "brown"],
    explode=[0.1, 0, 0, 0, 0],
    shadow=True,
)
plt.show()
